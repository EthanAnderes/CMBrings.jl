# %% [markdown]
# Modules
# ==============================

# %%
using LinearAlgebra
BLAS.set_num_threads(1)

using FFTW
FFTW.set_num_threads(5)

using XFields
using CMBrings
using CMBsphere
using CMBflat: PrQr # Eventually remove this

import FFTransforms as FT
import SphereTransforms as ST

using Spectra
using FieldLensing

using  LinearAlgebra
using  SparseArrays
import Dierckx
import NLopt

using DelimitedFiles
using LBblocks: @sblock
using PyPlot
using BenchmarkTools
using ProgressMeter

# %%
if isdefined(Main,:PlutoRunner)
    import PlutoUI
    hide_plots = false
elseif isdefined(Main, :IJulia) && Main.IJulia.inited
    hide_plots = false
else
    hide_plots = true
end
# Out:
# false

# %% [markdown]
# Set ring transforms
# ==============================

# %%
tmUS0, tmUS2, θ, φ, Ω, ringidx, tmS0 = @sblock let

    # size of the embedding full sphere
    # 𝕊nθ, 𝕊nφ = (3584, 4096-1)
    𝕊nθ, 𝕊nφ = (4096, 4096-1)

    # grid coords on full sphere
    θ𝕊, φ𝕊  = ST.pix(𝕊nθ, 𝕊nφ)

    # north and southern boundaries and the corresponding indices
    # Small strip at full resolution
    θnorth∂ = 2.5 #
    θsouth∂ = 2.72 # 2.7
   
    θrng    = findall(θnorth∂ .<= θ𝕊 .<= θsouth∂)
    ringidx = CartesianIndices((θrng[1]:θrng[end], 1:length(φ𝕊)))

    nθ, nφ  = size(ringidx)
    θ, φ  = θ𝕊[ringidx[:,1]], φ𝕊
    Ω     = ST.Ωpix(𝕊nθ, 𝕊nφ)[ringidx[:,1]]

    # Unitary transforms for spin0 and spin2
    T = Float64
    # T = Float32
    tmS0 = FT.:⊗(FT.𝕀(nθ), FT.𝕎(T, nφ, 2π)) |> x -> FT.unitary_scale(x)*x
    tmUS0 = FT.:⊗(FT.𝕀(nθ), FT.𝕎(Complex{T}, nφ, 2π)) |> x -> FT.unitary_scale(x)*x
    tmUS2 = FT.:⊗(FT.𝕀(nθ), FT.𝕎(Complex{T}, nφ, 2π)) |> x -> FT.unitary_scale(x)*x

    return tmUS0, tmUS2, θ, φ, Ω, ringidx, tmS0
end;

# %% [markdown]
# Mask and CMBring observation region
# ==============================

# %%
data_mask_init = @sblock let θ, φ

    # Default:
    pr_mat_init  = readdlm(joinpath(CMBrings.module_dir,"examples/artifacts/FastTransform_mask_nθ3072_nφ4095.csv"), ',', Bool)
    # Near-south pole mask:
    # pr_mat_init  = readdlm(joinpath(CMBrings.module_dir,"examples/artifacts/FastTransform_mask_mid2pole_nθ2560_nφ3071.csv"), ',', Bool)
    # South pole mask:
    # pr_mat_init  = readdlm(joinpath(CMBrings.module_dir,"examples/artifacts/FastTransform_mask_spole_nθ3072_nφ4095.csv"), ',', Bool)

    θ_mat_init, φ_mat_init = ST.pix(size(pr_mat_init)...)
    spline_mask = Dierckx.Spline2D(θ_mat_init, φ_mat_init, pr_mat_init, kx=1, ky=1, s=0.0)

    data_mask_init = spline_mask.(θ, φ') .> 0
    data_mask_init[1:15,:] .= 0
    data_mask_init[end - 15 + 1:end,:] .= 0


    return data_mask_init

end;
# Out:
# Internal error: encountered unexpected error in runtime:
# StackOverflowError()

# %%
Pr, Qr = @sblock let tmUS2, θ, φ, data_mask_init, QP_bdry=1e-5, fwhm′=150
    tmFlat = FT.𝕎(real(eltype_in(tmUS2)), size(data_mask_init), ((θ[2] - θ[1])*length(θ), 2π))
    pr0x, qr0x = PrQr(tmFlat, data_mask_init, fwhm′, fwhm′, QP_bdry)
    pr0 = Xmap(tmUS2, pr0x)
    qr0 = Xmap(tmUS2, qr0x)
    DiagOp(pr0), DiagOp(qr0)
end;

# %% [markdown]
# Localize lensing vector field to data mask.

# %%
Mϕ = @sblock let tmS0, θ, φ, data_mask_init, QP_bdry=1e-5, fwhm′=75
    tmFlat = FT.𝕎(real(eltype_in(tmS0)), size(data_mask_init), ((θ[2] - θ[1])*length(θ), 2π))
    pr0x, qr0x = PrQr(tmFlat, data_mask_init, fwhm′, fwhm′, QP_bdry)

    # mϕx = pr0x .+ qr0x
    mϕx = pr0x

    # make sure it hits zero and 1
    mϕx .-= minimum(mϕx)
    mϕx ./= maximum(mϕx)
    Mϕ    = DiagOp(Xmap(tmS0, mϕx))
    Mϕ
end;

# %% [markdown]
# Azimuthal ring mask

# %%
@sblock let ma=real.(Pr[:]), dma=data_mask_init, φ, θ, hide_plots
    hide_plots && return
    imgs = Dict(1=>dma, 2=>ma)
    txt  = Dict(1=>"pre-smoothed mask", 2=>"mask")
    fig, ax = CMBrings.diskplot(
        imgs, φ', π.-θ;
        txt=txt,
        figsize=(10,8), nrows=1, fontsize=14
    )
    return nothing
end
# Out:
# Figure(PyObject <Figure size 1000x800 with 4 Axes>)

# %% [markdown]
# Plot √Ωpix over ring θ's

# %%
@sblock let θ, φ, Ω, hide_plots
    hide_plots && return
    fig,ax = subplots(1)
    ax.plot(θ, rad2deg.(sqrt.(Ω)).*60, label="sqrt pixel area (arcmin)")
    ax.plot(θ, zero(θ) .+ rad2deg.(θ[2] - θ[1]).*60, label="Δθ (arcmin)")
    # ax.plot(θ, zero(θ) .+ rad2deg.(φ[2] - φ[1]).*60, label="Δφ (arcmin)")
    ax.set_xlabel(L"polar coordinate $\theta$")
    ax.legend()
    return nothing
end
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
(length(θ), length(φ))
# Out:
# (287, 4095)

# %% [markdown]
# Spectral densities
# ==============================

# %% [markdown]
# ϕϕ, EB spectra

# %%
eeℓ, bbℓ, ẽeℓ, b̃bℓ, ϕϕℓ, ℓvec = @sblock let

    r  = 0.01

    lmax = 11000
    l = 0:lmax
    cld = Spectra.camb_cls(;lmax=lmax, r)

    eesl = cld[:unlen_scalar] |> x->(x[:Cee] ./ x[:factor_on_cl_cmb])
    eetl = cld[:unlen_tensor] |> x->(x[:Cee] ./ x[:factor_on_cl_cmb])
    eel  = eesl .+ eetl
    eel[1] = 0

    bbsl = cld[:unlen_scalar] |> x->(x[:Cbb] ./ x[:factor_on_cl_cmb])
    bbtl = cld[:unlen_tensor] |> x->(x[:Cbb] ./ x[:factor_on_cl_cmb])
    # note: bbsl == 0
    bbl    = bbsl .+ bbtl
    bbl[1] = 0

    ẽesl   = cld[:len_scalar] |> x->(x[:Cee] ./ x[:factor_on_cl_cmb])
    ẽel    = ẽesl .+ eetl # we only have lensed spectra for scalar
    ẽel[1] = 0

    b̃bsl   = cld[:len_scalar] |> x->(x[:Cbb] ./ x[:factor_on_cl_cmb])
    b̃bl    = b̃bsl .+ eetl # we only have lensed spectra for scalar
    b̃bl[1] = 0

    ϕϕl    = cld[:phi] |> x->(x[:Cϕϕ] ./ x[:factor_on_cl_phi])
    ϕϕl[1] =  0

    return eel, bbl, ẽel, b̃bl, ϕϕl, l

end;

# %% [markdown]
# EB ring operator
# ==============================

# %%
EB_ring = @sblock let  eeℓ, bbℓ, ℓvec, θ, φ,

    covPβ = Spectra.βcovSpin2(ℓvec, eeℓ, bbℓ;
        # n_grid::Int = 100_000,
        # β_grid = range(0, π^(1/3), length=n_grid).^3,
    );

    nθ = length(θ)
    nφ = length(φ)

    ptmW = FT.FFTW.plan_fft(Vector{ComplexF64}(undef, nφ), flags=FT.FFTW.MEASURE)
    Γdjk = zeros(ComplexF64, nφ)
    Cdjk = zeros(ComplexF64, nφ)

    # T = ComplexF32
    T = ComplexF64
    Γdb  = Matrix{T}[zeros(T, nθ, nθ) for ℓ = 1:nφ]
    Cdb  = Matrix{T}[zeros(T, nθ, nθ) for ℓ = 1:nφ]

    prgss = Progress(nθ, 1, "Computing EB cov operator ...")
    for k = 1:nθ
        for j = 1:nθ
            θ1, θ2, φ1 = θ[j], θ[k], φ[1]
            β  =  Spectra.geoβ.(θ1, θ2, φ1, φ)
            covPP̄, covPP = covPβ(β)
            covPP̄ .*= Spectra.multPP̄.(θ1, θ2, φ1, φ)
            covPP .*= Spectra.multPP.(θ1, θ2, φ1, φ)
            mul!(Γdjk, ptmW, covPP̄)
            mul!(Cdjk, ptmW, covPP)
            for ℓ = 1:nφ
                @inbounds Γdb[ℓ][j,k] = Γdjk[ℓ]
                @inbounds Cdb[ℓ][j,k] = Cdjk[ℓ]
            end
        end
        next!(prgss)
    end

    return CMBrings.ComplexCircRings(Γdb, Cdb)
end;
# Out:
# Computing EB cov operator ...100%|██████████████████████| Time: 0:01:57

# %% [markdown]
# Beam
# ==============================

# %%
beamℓ = @sblock let ℓvec
    beamfwhm     = 3.0 |> arcmin -> deg2rad(arcmin/60)
    # beamfwhm  = 25.0 |> arcmin -> deg2rad(arcmin/60)

    σ² = beamfwhm^2 / 8 / log(2)
    bℓ = @. exp( - σ²*ℓvec*(ℓvec+1) / 2)

    # ℓcut = 200
    # bℓ .*= ℓvec .< ℓcut

    return bℓ
end;

Beam_ring = @sblock let beamℓ, ℓvec, θ, φ, Ω

    covBeamβ = Spectra.βcovSpin0(ℓvec, beamℓ)

    nθ=length(θ)
    nφ=length(φ)

    ptmW = FT.FFTW.plan_fft(Vector{ComplexF64}(undef, nφ), flags=FT.FFTW.MEASURE)
    Γdjk = zeros(ComplexF64, nφ)

    # T    = Float32
    T    = Float64
    Γdb  = Matrix{T}[zeros(T, nθ, nθ) for ℓ = 1:nφ]
    Cdb  = typeof(false*I(nθ))[false*I(nθ) for ℓ = 1:nφ]

    prgss = Progress(nθ, 1, "Computing the beam operator ...")
    for k = 1:nθ
        for j = 1:nθ
            θ1, θ2, φ1 = θ[j], θ[k], φ[1]
            Ωk    = Ω[k]
            β     =  Spectra.geoβ.(θ1, θ2, φ1, φ)
            covIĪ = complex.(covBeamβ(β))
            mul!(Γdjk, ptmW, covIĪ)
            for ℓ = 1:nφ
                @inbounds Γdb[ℓ][j,k] = real(Γdjk[ℓ]) * Ωk
            end
        end
        next!(prgss)
    end

    return CMBrings.ComplexCircRings(Γdb, Cdb)
end;
# Out:
# Computing the beam operator ...100%|████████████████████| Time: 0:00:53

# %% [markdown]
# Noise
# ==============================

# %%
Noise_ring, μK′n = @sblock let μK′n = 1.5, θ, φ, Ω

    # T = Float32
    T = Float64
    nθ=length(θ)
    nφ=length(φ)

    μKᵒn = μK′n / 60
    σ²   = deg2rad(μKᵒn)^2
    σ²_Ω = T.(σ²./Ω)

    Γdb  = typeof(Diagonal(σ²_Ω))[Diagonal(σ²_Ω) for ℓ = 1:nφ]
    Cdb  = typeof(false*I(nθ))[false*I(nθ) for ℓ = 1:nφ]

    return CMBrings.ComplexCircRings(Γdb, Cdb), μK′n
end;

# %% [markdown]
# Φ operator
# ==============================

# %%
Φ_ring = @sblock let ϕϕℓ, ℓvec, θ, φ, Ω

    covΦβ = Spectra.βcovSpin0(ℓvec, ϕϕℓ)
    nθ=length(θ)
    nφ=length(φ)

    ptmW = FT.FFTW.plan_fft(Vector{ComplexF64}(undef, nφ), flags=FT.FFTW.MEASURE)
    Γdjk = zeros(ComplexF64, nφ)

    # T    = Float32
    T    = Float64
    Γdb  = Matrix{T}[zeros(T, nθ, nθ) for ℓ = 1:nφ]
    # Cdb  = Matrix{T}[zeros(T, nθ, nθ) for ℓ = 1:nφ]
    Cdb  = typeof(false*I(nθ))[false*I(nθ) for ℓ = 1:nφ]

    prgss = Progress(nθ, 1, "Computing the Φ operator ...")
    for k = 1:nθ
        for j = 1:nθ
            θ1, θ2, φ1 = θ[j], θ[k], φ[1]
            Ωk    = Ω[k]
            β     =  Spectra.geoβ.(θ1, θ2, φ1, φ)
            covIĪ = complex.(covΦβ(β))
            mul!(Γdjk, ptmW, covIĪ)
            for ℓ = 1:nφ
                # TODO: double check this ....
                # @inbounds Γdb[ℓ][j,k] = real(Γdjk[ℓ] / 2)
                # @inbounds Cdb[ℓ][j,k] = real(Γdjk[ℓ] / 2)
                @inbounds Γdb[ℓ][j,k] = real.(Γdjk[ℓ])
            end
        end
        next!(prgss)
    end

    return CMBrings.ComplexCircRings(Γdb, Cdb)
end;
# Out:
# Computing the Φ operator ...100%|███████████████████████| Time: 0:00:52

# %% [markdown]
# Gradients Set sparse increment matrices for non-FFT lensing
# ==================================================

# %%
function generate_∇!_∇!ϕ_1storder(tmS0::Transform{Tf,d}, θℝ, φℝ) where {Tf,d}
    Δθℝ, Δφℝ = θℝ[2] - θℝ[1], φℝ[2] - φℝ[1]

    ∂θ′ = spdiagm(
            0 => fill(-1,length(θℝ)),
            1 => fill(1,length(θℝ)-1),
        )
    ∂θ′[end,1] =  1
    ∂θ = Tf(1 / (Δθℝ)) * ∂θ′
   

    ∂φ  = spdiagm(
        0 => fill(-1,length(φℝ)),
        1 => fill(1,length(φℝ)-1)
    )
    ∂φ[end,1] =  1
    ∂φᵀ = transpose(Tf(1 / (Δφℝ)) * ∂φ)
    
    ∇!   = CMBrings.Nabla!((∂θ - ∂θ')/2, (∂φᵀ - ∂φᵀ')/2)
    ∇!_ϕ = CMBrings.Nabla!(∂θ, ∂φᵀ)

    return ∇!, ∇!_ϕ
end


function generate_lense_sublense(;
        tmS0, θ, mv1x=1, mv2x=1,
        ∇!,  ∇!_ϕ, ## subidx, sub_∇!,
        nsteps_lensing=14
        )

    # ∇!_ϕ used in ϕ2v! and ϕ2vᴴ!
    # ∇! used in Ł
    # sub_∇! used in sub_Ł

    sin⁻²θ = @. csc(θ)^2
    mvx₁ = ones(size(θ)) .* mv1x
    mvx₂ = sin⁻²θ .* mv2x

    ϕ2v! = function (v::NTuple{2,Array}, ϕ::Array)
        ∇!_ϕ(v, ϕ)
        v[1] .*= mvx₁
        v[2] .*= mvx₂
        v
    end

    ϕ2vᴴ! = function (ϕ::Array, v::NTuple{2,Array})
        mv = (similar(v[1]), similar(v[2]))
        ∇!_ϕ'(mv, (mvx₁.*v[1], mvx₂.*v[2]) )
        ϕ .= mv[1] .+ mv[2]
        ϕ
    end

    Ł = function (ϕ_az::Xfield)
        ϕ = ϕ_az[:]
        v = (similar(ϕ), similar(ϕ))
        ϕ2v!(v,ϕ)
        FieldLensing.ArrayLense(v, ∇!, 0, 1, nsteps_lensing)
    end

    Ł, ϕ2v!, ϕ2vᴴ!, ∇!
end

∇!,  ∇!_ϕ = generate_∇!_∇!ϕ_1storder(tmS0, θ, φ)

Ł, ϕ2v!, ϕ2vᴴ!, ∇! = generate_lense_sublense(;
        tmS0=tmS0, θ=θ,
        mv1x=Mϕ[:], mv2x=Mϕ[:],
        ∇!,  ∇!_ϕ, ## subidx, sub_∇!,
        nsteps_lensing=11
);

# %% [markdown]
# simulation
# ==============================

# %%
@time qu = CMBrings.map_ring(
    (fℓ, Σℓ) -> sqrt(Hermitian(Σℓ)) * fℓ,
    Xmap(tmUS2, randn(eltype_in(tmUS2), size_in(tmUS2))),
    EB_ring,
)

@time no = CMBrings.map_ring(
    (fℓ, Σℓ) -> sqrt(Hermitian(Matrix(Σℓ))) * fℓ,
    Xmap(tmUS2, randn(eltype_in(tmUS2), size_in(tmUS2))),
    Noise_ring,
)

@time ϕ = CMBrings.map_ring(
    (fℓ, Σℓ) -> sqrt(Symmetric(Matrix(Σℓ))) * fℓ,
    Xmap(tmS0, randn(eltype_in(tmS0), size_in(tmS0))),
    Φ_ring,
)

d = Pr * (Beam_ring * Ł(ϕ) * qu + no)
# Out:
#  90.767483 seconds (6.70 M allocations: 66.800 GiB, 1.32% gc time, 0.34% compilation time)
#  23.508094 seconds (11.61 M allocations: 31.550 GiB, 3.41% gc time, 5.90% compilation time)
#  29.186547 seconds (2.44 M allocations: 52.325 GiB, 3.41% gc time, 0.25% compilation time)
# Xmap{FFTransforms.𝕎{ComplexF64, 2, Float64, Float64}, ComplexF64, ComplexF64, 2}(FFTransforms.𝕎{ComplexF64, 2, Float64, Float64}((287, 4095), (false, true), 0.015626907697949846, (287.0, 6.283185307179586)), ComplexF64[0.0 - 0.0im 0.0 - 0.0im … 0.0 + 0.0im 0.0 - 0.0im; 0.0 - 0.0im 0.0 - 0.0im … 0.0 + 0.0im 0.0 - 0.0im; … ; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 - 0.0im; 0.0 - 0.0im 0.0 - 0.0im … 0.0 - 0.0im 0.0 - 0.0im])

# %% [markdown]
# MixFlow
# ==============================

# %%
Ð⁻¹ = @sblock let ẽeℓ, b̃bℓ, ℓvec, θ, φ, EB_ring, Noise_ring

    covPβ = Spectra.βcovSpin2(ℓvec, ẽeℓ, b̃bℓ)

    nθ = length(θ)
    nφ = length(φ)

    ptmW = FT.FFTW.plan_fft(Vector{ComplexF64}(undef, nφ), flags=FT.FFTW.MEASURE)
    Γdjk = zeros(ComplexF64, nφ)
    Cdjk = zeros(ComplexF64, nφ)
    # T    = ComplexF32
    T    = ComplexF64
    Γdb  = Matrix{T}[zeros(T, nθ, nθ) for ℓ = 1:nφ]
    Cdb  = Matrix{T}[zeros(T, nθ, nθ) for ℓ = 1:nφ]

    prgss = Progress(nθ, 1, "Computing EB̃_ring operator ...")
    for k = 1:nθ
        for j = 1:nθ
            θ1, θ2, φ1 = θ[j], θ[k], φ[1]
            β  =  Spectra.geoβ.(θ1, θ2, φ1, φ)
            covPP̄, covPP = covPβ(β)
            covPP̄ .*= Spectra.multPP̄.(θ1, θ2, φ1, φ)
            covPP .*= Spectra.multPP.(θ1, θ2, φ1, φ)
            mul!(Γdjk, ptmW, covPP̄)
            mul!(Cdjk, ptmW, covPP)
            for ℓ = 1:nφ
                @inbounds Γdb[ℓ][j,k] = Γdjk[ℓ]
                @inbounds Cdb[ℓ][j,k] = Cdjk[ℓ]
            end
        end
        next!(prgss)
    end

    EB̃_ring = CMBrings.ComplexCircRings(Γdb, Cdb)

    Ð⁻¹ =  CMBrings.map_ring(
        (EBℓ, EB̃ℓ, Nℓ) -> sqrt(Hermitian(EBℓ)) / sqrt(Hermitian(EB̃ℓ + 4*Nℓ)),
        EB_ring, EB̃_ring, Noise_ring,
    );

    return Ð⁻¹
end;
# Out:
# Computing EB̃_ring operator ...100%|████████████████████| Time: 0:01:49

# %% [markdown]
# Uncertainty for ϕ based on iterative quadratic estimate
# ==============================

# %%
import CMBflat

N0ℓ, NΦNℓ =  @sblock let n_iter = 5, eeℓ, bbℓ, ϕϕℓ, beamℓ, nnℓ = deg2rad(μK′n / 60)^2 .+ zero(ℓvec), ℓvec

    T_fld = Float64

    nθ, nφ  = 512, 512
    periodθ = T_fld(nθ * deg2rad(3.5 / 60))
    periodφ = T_fld(nφ * deg2rad(3.5 / 60))
    tm    = FT.𝕎(T_fld, (nθ, nφ), (periodθ, periodφ))
    tmΦ   = FT.ordinary_scale(tm) * tm
    tmEB  = CMBflat.QU2EB(T_fld, (nθ, nφ), (periodθ, periodφ))

    Idx  = round.(Int,FT.wavenum(tmΦ)) .+ 1
    ecl  = map(i -> getindex(eeℓ, i), Idx)
    bcl  = map(i -> getindex(bbℓ, i), Idx)
    ϕcl  = map(i -> getindex(ϕϕℓ, i), Idx)
    ncl  = map(i -> getindex(nnℓ, i), Idx)
    bmcl = map(i -> getindex(beamℓ, i), Idx)

    EBcov = DiagOp(Xfourier(tmEB, cat(ecl,bcl;dims=3)))
    Ncov  = DiagOp(Xfourier(tmEB, cat(ncl,ncl;dims=3)))
    Bm    = DiagOp(Xfourier(tmEB, cat(bmcl,bmcl;dims=3)))
    Φcov  = DiagOp(Xfourier(tmΦ, ϕcl))

    # -----
    Ncov_local = Ncov / Bm^2
    Ncov_local.f.fd[real.(Bm.f.fd) .<= 0] .= Inf
    Ncov_local.f.fd[1,1,1] = Inf
    Ncov_local.f.fd[1,1,2] = Inf

    # ----- EBcov_local: unlensed signal
    EBcov_local = deepcopy(EBcov)

    # ----- Nϕ with tot power == EBcov_local + B̃fromE + Ncov_local
    # In the iterations B̃fromE will get reduced.
    B̃fromE  = CMBflat.lnB_matpwr(tmΦ, EBcov_local[:El], Φcov[!]) |>
                    x-> Xfourier(tmEB, 0, x) |>
                    DiagOp
    Nϕ  = CMBflat.N0ℓ_EB(
        tmΦ,
        EBcov_local,
        inv(EBcov_local + B̃fromE + Ncov_local), # inv total power: signal + effective noise
    )
    Nϕ.f.fd[real.(Nϕ.f.fd) .<= 0] .= Inf
    Nϕ.f.fd[1,1] = Inf

    for cntr = 1:n_iter

        wf_B̃fromE  = CMBflat.lnB_matpwr(
            tmΦ,
            (EBcov_local^2 * inv(EBcov_local + Ncov_local))[:El],
            (Φcov^2 * inv(Φcov + Nϕ))[!],
        ) |> x-> Xfourier(tmEB, 0, x) |> DiagOp

        Nϕ  = CMBflat.N0ℓ_EB(
            tmΦ,
            EBcov_local,
            inv(EBcov_local + B̃fromE - wf_B̃fromE + Ncov_local), # inv total power: signal + effective noise
        )
        Nϕ.f.fd[real.(Nϕ.f.fd) .<= 0] .= Inf
        Nϕ.f.fd[1,1] = Inf

    end

    k      = FT.wavenum(tmΦ)[:,1]
    k4n0ck = k.^4 .* real.(Nϕ[!][:,1])

    spline_k4n0ck = Dierckx.Spline1D(
        vcat(2,k[3:end]), vcat(k4n0ck[3], k4n0ck[3:end])
        ; k=1, bc="zero",
    )

    N0ℓ = spline_k4n0ck.(ℓvec) ./ ℓvec.^4
    N0ℓ[real.(N0ℓ) .<= 0] .= Inf
    N0ℓ[isnan.(N0ℓ)]      .= Inf
    NΦNℓ = @. inv(inv(N0ℓ) + inv(ϕϕℓ))

    N0ℓ, NΦNℓ
end;

# %%
NΦN_ring = @sblock let NΦNℓ, ℓvec, θ, φ, Ω

    covΦβ = Spectra.βcovSpin0(ℓvec, NΦNℓ)
    nθ=length(θ)
    nφ=length(φ)

    # ptmW = FT.FFTW.plan_fft(Vector{ComplexF64}(undef, nφ), flags=FT.FFTW.PATIENT)
    ptmW = FT.FFTW.plan_fft(Vector{ComplexF64}(undef, nφ), flags=FT.FFTW.MEASURE)
    Γdjk = zeros(ComplexF64, nφ)

    # T    = Float32
    T    = Float64
    Γdb  = Matrix{T}[zeros(T, nθ, nθ) for ℓ = 1:nφ]
    # Cdb  = Matrix{T}[zeros(T, nθ, nθ) for ℓ = 1:nφ]
    Cdb  = typeof(false*I(nθ))[false*I(nθ) for ℓ = 1:nφ]

    prgss = Progress(nθ, 1, "Computing the NΦN operator ...")
    for k = 1:nθ
        for j = 1:nθ
            θ1, θ2, φ1 = θ[j], θ[k], φ[1]
            Ωk    = Ω[k]
            β     =  Spectra.geoβ.(θ1, θ2, φ1, φ)
            covIĪ = complex.(covΦβ(β))
            mul!(Γdjk, ptmW, covIĪ)
            for ℓ = 1:nφ
                @inbounds Γdb[ℓ][j,k] = real.(Γdjk[ℓ])
            end
        end
        next!(prgss)
    end
    return CMBrings.ComplexCircRings(Γdb, Cdb)
end;
# Out:
# Computing the NΦN operator ...100%|█████████████████████| Time: 0:00:52

# %% [markdown]
# Preconditioner
# ==============================

# %%
@time Precon⁻¹_ring = @sblock let EB_ring, Beam_ring, Noise_ring, pr_col=Pr[:][:,2*end÷10], qr_col=Qr[:][:,2*end÷10]

    # T = ComplexF32
    T = ComplexF64
    Precon⁻¹ = CMBrings.ComplexCircRings(EB_ring.nblks, EB_ring.nside, Matrix{T}, Matrix{T})

    prgss = Progress(Precon⁻¹.nblks÷2+1, 1, "Computing the inverse preconditioner ...")
    Threads.@threads for ℓ = 1:Precon⁻¹.nblks÷2+1
        Bm = Beam_ring[ℓ]
        EB = EB_ring[ℓ]
        No = Noise_ring[ℓ]
        Ωℓ = Bm * EB * Bm' + No
        Precon⁻¹[ℓ] = pinv(Ωℓ) ## pinv(Ωℓ)
        next!(prgss)
    end

    return Precon⁻¹
end;
# Out:
# Computing the inverse preconditioner ...100%|███████████| Time: 0:04:15
# 257.047027 seconds (3.54 M allocations: 169.046 GiB, 2.29% gc time, 0.01% compilation time)

# %% [markdown]
# Now do some iterations ...
# ==============================

# %%
# ------ initalize
gwf = 0*d
ϕ_cr  = 0*ϕ
# special for this noise
Noise_ring⁻¹ = CMBrings.map_ring(Nℓ->diagm(1 ./ diag(Nℓ)), Noise_ring);

# %%
@showprogress for otr = 1:60
# @showprogress for otr = 2:50
    global f_cr, gwf, hst
    global f′_cr, ϕ_cr, ∇ϕ_cr

    # ------ update field
    @time f_cr, gwf, hst = CMBrings.update_f(
        (otr==1) ? DiagOp(Xmap(tmUS2,1)) : Ł(ϕ_cr), # slot for Łϕ
        EB_ring;
        data=Xmap(d),
        Pr, Qr,
        Bm=Beam_ring, No=Noise_ring, Pc⁻¹=Precon⁻¹_ring,
        ginit=Xmap(gwf),
        pcg_nsteps = (otr==1) ? 300 : 200, # 175, ## 200,
        pcg_rel_tol=1e-10
    );
    @show hst[end]
    f′_cr =  Ł(ϕ_cr) * (Ð⁻¹ \ f_cr)
    @show CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data=d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹)

    # ------ ϕ gradient
    # @time gradϕ = CMBrings.∇ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data=d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹, ϕ2v!, ϕ2vᴴ!, ∇!, grad_nsteps=11)
    @time gradϕ = CMBrings.∇ll_ϕf′_usingf(ϕ_cr, f_cr, Φ_ring, EB_ring; data=d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹, ϕ2v!, ϕ2vᴴ!, ∇!, grad_nsteps=11)
    @time ∇ϕ_cr = NΦN_ring * gradϕ

    # ------ linesearch
    @time β = CMBrings.linesearch_ϕf′(
        ∇ϕ_cr, ϕ_cr, f′_cr, Φ_ring, EB_ring;
        data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹,
        eval_max = 200, startval = 0.001, ftol_abs = 10, solver = :LN_COBYLA,
        # eval_max = 250, startval = 0.001, ftol_abs = 1, solver = :LN_COBYLA,
    )
    @show β

    # ------ update ϕ_cr
    ϕ_cr += β * ∇ϕ_cr
end
# Out:
# Progress:  38%|███████████████▊                         |  ETA: 19:41:3558
# 1077.099366 seconds (5.68 G allocations: 537.566 GiB, 33.73% gc time)
# hst[end] = 0.07019798613524224
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -2.604348450058017e6
#  47.807919 seconds (272.88 k allocations: 57.247 GiB, 9.17% gc time)
#   0.134204 seconds (6.36 k allocations: 63.793 MiB)
# 375.139617 seconds (143.53 M allocations: 563.946 GiB, 6.82% gc time)
# β = 0.0062499999999999995
# 1325.321344 seconds (3.79 G allocations: 454.185 GiB, 24.77% gc time)
# hst[end] = 0.0706305150590981
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -310334.3555311381
#  46.917186 seconds (272.87 k allocations: 57.247 GiB, 9.06% gc time)
#   0.061072 seconds (6.36 k allocations: 63.793 MiB)
# 523.107811 seconds (200.94 M allocations: 789.525 GiB, 6.77% gc time)
# β = 0.023499999999999997
# 1321.999990 seconds (3.79 G allocations: 454.185 GiB, 24.82% gc time)
# hst[end] = 0.03422529984001314
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -214976.19008995005
#  47.123535 seconds (272.82 k allocations: 57.247 GiB, 9.12% gc time)
#   0.061665 seconds (6.36 k allocations: 63.793 MiB)
# 523.203051 seconds (200.94 M allocations: 789.525 GiB, 6.77% gc time)
# β = 0.046
# 1322.353593 seconds (3.79 G allocations: 454.185 GiB, 24.81% gc time)
# hst[end] = 0.01936964780031918
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -192666.39752827646
#  46.873155 seconds (272.91 k allocations: 57.247 GiB, 9.16% gc time)
#   0.062294 seconds (6.36 k allocations: 63.793 MiB)
# 559.141607 seconds (215.29 M allocations: 845.919 GiB, 6.81% gc time)
# β = 0.04
# 1330.173371 seconds (3.79 G allocations: 454.185 GiB, 24.61% gc time)
# hst[end] = 0.01291392691050381
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -184979.39228556896
#  46.787233 seconds (272.88 k allocations: 57.247 GiB, 9.11% gc time)
#   0.061726 seconds (6.36 k allocations: 63.793 MiB)
# 448.244744 seconds (172.23 M allocations: 676.735 GiB, 6.78% gc time)
# β = 0.061
# 1324.682112 seconds (3.79 G allocations: 454.185 GiB, 24.76% gc time)
# hst[end] = 0.009576036974533129
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -182355.51447916712
#  46.806277 seconds (272.91 k allocations: 57.247 GiB, 9.12% gc time)
#   0.061425 seconds (6.36 k allocations: 63.793 MiB)
# 483.659832 seconds (186.59 M allocations: 733.130 GiB, 6.78% gc time)
# β = 0.043
# 1321.294146 seconds (3.79 G allocations: 454.185 GiB, 24.81% gc time)
# hst[end] = 0.008484424002029638
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -181501.4912444734
#  46.880764 seconds (272.86 k allocations: 57.247 GiB, 9.12% gc time)
#   0.061420 seconds (6.36 k allocations: 63.793 MiB)
# 447.596528 seconds (172.23 M allocations: 676.735 GiB, 6.78% gc time)
# β = 0.061
# 1324.596520 seconds (3.79 G allocations: 454.185 GiB, 24.78% gc time)
# hst[end] = 0.007265437000373276
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -180584.42818975073
#  46.956726 seconds (272.87 k allocations: 57.247 GiB, 9.09% gc time)
#   0.061777 seconds (6.36 k allocations: 63.793 MiB)
# 446.700501 seconds (172.23 M allocations: 676.735 GiB, 6.79% gc time)
# β = 0.037000000000000005
# 1323.147920 seconds (3.79 G allocations: 454.185 GiB, 24.81% gc time)
# hst[end] = 0.006977062598701745
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -180293.88347398525
#  47.055828 seconds (272.85 k allocations: 57.247 GiB, 9.14% gc time)
#   0.062948 seconds (6.36 k allocations: 63.793 MiB)
# 486.738949 seconds (186.59 M allocations: 733.130 GiB, 6.77% gc time)
# β = 0.073
# 1337.822712 seconds (3.79 G allocations: 454.185 GiB, 24.79% gc time)
# hst[end] = 0.00622771897519659
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -179753.25684398628
#  46.879743 seconds (272.86 k allocations: 57.247 GiB, 9.05% gc time)
#   0.061007 seconds (6.36 k allocations: 63.793 MiB)
# 412.071630 seconds (157.88 M allocations: 620.341 GiB, 6.78% gc time)
# β = 0.031
# 1322.441449 seconds (3.79 G allocations: 454.185 GiB, 24.84% gc time)
# hst[end] = 0.006283315265577085
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -179610.38655273675
#  46.821672 seconds (272.89 k allocations: 57.247 GiB, 9.11% gc time)
#   0.061628 seconds (6.36 k allocations: 63.793 MiB)
# 523.542459 seconds (200.94 M allocations: 789.525 GiB, 6.77% gc time)
# β = 0.133
# 1323.589986 seconds (3.79 G allocations: 454.185 GiB, 24.83% gc time)
# hst[end] = 0.005713006932112814
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -179270.51039381674
#  46.976621 seconds (272.87 k allocations: 57.247 GiB, 9.17% gc time)
#   0.062934 seconds (6.36 k allocations: 63.793 MiB)
# 484.479596 seconds (186.59 M allocations: 733.130 GiB, 6.77% gc time)
# β = 0.024999999999999994
# 1323.809855 seconds (3.79 G allocations: 454.185 GiB, 24.86% gc time)
# hst[end] = 0.005490124392595779
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -179004.95143022374
#  47.011823 seconds (272.85 k allocations: 57.247 GiB, 9.14% gc time)
#   0.062770 seconds (6.36 k allocations: 63.793 MiB)
# 559.347161 seconds (215.29 M allocations: 845.919 GiB, 6.78% gc time)
# β = 0.289
# 1324.043886 seconds (3.79 G allocations: 454.185 GiB, 24.79% gc time)
# hst[end] = 0.005874781042549085
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -179068.10771805304
#  46.917096 seconds (272.88 k allocations: 57.247 GiB, 9.14% gc time)
#   0.062509 seconds (6.36 k allocations: 63.793 MiB)
# 446.878373 seconds (172.23 M allocations: 676.735 GiB, 6.79% gc time)
# β = 0.022
# 1334.171458 seconds (3.79 G allocations: 454.185 GiB, 24.83% gc time)
# hst[end] = 0.005010630916389144
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -178654.45371272427
#  47.547577 seconds (272.83 k allocations: 57.247 GiB, 9.07% gc time)
#   0.061740 seconds (6.36 k allocations: 63.793 MiB)
# 636.380655 seconds (244.00 M allocations: 958.708 GiB, 6.79% gc time)
# β = 0.313
# 1324.141346 seconds (3.79 G allocations: 454.185 GiB, 24.78% gc time)
# hst[end] = 0.006194401440150802
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -178956.99722021536
#  46.828290 seconds (272.87 k allocations: 57.247 GiB, 9.12% gc time)
#   0.061001 seconds (6.36 k allocations: 63.793 MiB)
# 409.321439 seconds (157.88 M allocations: 620.341 GiB, 6.77% gc time)
# β = 0.031
# 1326.276928 seconds (3.79 G allocations: 454.185 GiB, 24.78% gc time)
# hst[end] = 0.004971226936097304
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -178320.09492244595
#  46.960698 seconds (272.89 k allocations: 57.247 GiB, 9.11% gc time)
#   0.062358 seconds (6.36 k allocations: 63.793 MiB)
# 483.065041 seconds (186.59 M allocations: 733.130 GiB, 6.79% gc time)
# β = 0.121
# 1324.239095 seconds (3.79 G allocations: 454.185 GiB, 24.80% gc time)
# hst[end] = 0.005286606533469601
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -178282.6712244618
#  46.736433 seconds (272.87 k allocations: 57.247 GiB, 9.34% gc time)
#   0.062410 seconds (6.36 k allocations: 63.793 MiB)
# 519.224378 seconds (200.94 M allocations: 789.525 GiB, 6.82% gc time)
# β = 0.033999999999999996
# 1324.330439 seconds (3.79 G allocations: 454.185 GiB, 24.80% gc time)
# hst[end] = 0.0051482461617175885
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -178151.34550092707
#  46.862743 seconds (272.87 k allocations: 57.247 GiB, 9.19% gc time)
#   0.061414 seconds (6.36 k allocations: 63.793 MiB)
# 481.229308 seconds (186.59 M allocations: 733.130 GiB, 6.79% gc time)
# β = 0.073
# 1321.443637 seconds (3.79 G allocations: 454.185 GiB, 24.81% gc time)
# hst[end] = 0.004965418719741414
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -177906.18862433653
#  46.844678 seconds (272.87 k allocations: 57.247 GiB, 9.10% gc time)
#   0.062170 seconds (6.36 k allocations: 63.793 MiB)
# 407.776617 seconds (157.88 M allocations: 620.341 GiB, 6.83% gc time)
# β = 0.031000000000000003
# 1327.256848 seconds (3.79 G allocations: 454.185 GiB, 24.79% gc time)
# hst[end] = 0.004780356601723158
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -177779.82702039866
#  46.815553 seconds (272.87 k allocations: 57.247 GiB, 9.21% gc time)
#   0.062393 seconds (6.36 k allocations: 63.793 MiB)
# 558.050851 seconds (215.29 M allocations: 845.919 GiB, 6.78% gc time)
# β = 0.16899999999999998
# 1324.539496 seconds (3.79 G allocations: 454.185 GiB, 24.80% gc time)
# hst[end] = 0.004368355980074972
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -177600.59171575806
#  46.833553 seconds (272.90 k allocations: 57.247 GiB, 9.14% gc time)
#   0.062190 seconds (6.36 k allocations: 63.793 MiB)
# 483.766897 seconds (186.59 M allocations: 733.130 GiB, 6.80% gc time)
# β = 0.024999999999999998
# 1328.010065 seconds (3.79 G allocations: 454.185 GiB, 24.81% gc time)
# hst[end] = 0.0042990661989548325
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -177492.00910085565
#  46.957147 seconds (272.91 k allocations: 57.247 GiB, 9.16% gc time)
#   0.062180 seconds (6.36 k allocations: 63.793 MiB)
# 593.858876 seconds (229.64 M allocations: 902.314 GiB, 6.79% gc time)
# β = 0.33699999999999997
# 1326.128036 seconds (3.79 G allocations: 454.185 GiB, 24.77% gc time)
# hst[end] = 0.004436415303309944
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -177478.08436149918
# Progress:  77%|███████████████████████████████▍         |  ETA: 7:28:15m
#  46.788023 seconds (272.89 k allocations: 57.247 GiB, 9.11% gc time)
#   0.061112 seconds (6.36 k allocations: 63.793 MiB)
# 447.037763 seconds (172.23 M allocations: 676.735 GiB, 6.81% gc time)
# β = 0.022
# 1321.151213 seconds (3.79 G allocations: 454.185 GiB, 24.84% gc time)
# hst[end] = 0.004041094837453768
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -177267.56803320145
#  46.915601 seconds (272.87 k allocations: 57.247 GiB, 9.10% gc time)
#   0.062846 seconds (6.36 k allocations: 63.793 MiB)
# 521.860791 seconds (200.94 M allocations: 789.525 GiB, 6.77% gc time)
# β = 0.385
# 1324.867900 seconds (3.79 G allocations: 454.185 GiB, 24.78% gc time)
# hst[end] = 0.005216331148251756
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -177564.80342435525
#  46.885855 seconds (272.89 k allocations: 57.247 GiB, 9.11% gc time)
#   0.062231 seconds (6.36 k allocations: 63.793 MiB)
# 372.918958 seconds (143.53 M allocations: 563.946 GiB, 6.78% gc time)
# β = 0.025
# 1324.207246 seconds (3.79 G allocations: 454.185 GiB, 24.81% gc time)
# hst[end] = 0.003875529838572586
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -177058.06444560835
#  46.782486 seconds (272.85 k allocations: 57.247 GiB, 9.19% gc time)
#   0.061912 seconds (6.36 k allocations: 63.793 MiB)
# 446.571012 seconds (172.23 M allocations: 676.735 GiB, 6.78% gc time)
# β = 0.061000000000000006
# 1324.095188 seconds (3.79 G allocations: 454.185 GiB, 24.78% gc time)
# hst[end] = 0.005341428805080565
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -177400.53057298547
#  47.127572 seconds (272.88 k allocations: 57.247 GiB, 9.15% gc time)
#   0.062773 seconds (6.36 k allocations: 63.793 MiB)
# 486.474913 seconds (186.59 M allocations: 733.130 GiB, 6.80% gc time)
# β = 0.055
# 1321.863903 seconds (3.79 G allocations: 454.185 GiB, 24.85% gc time)
# hst[end] = 0.0037234073031418686
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176795.4562850522
#  46.951680 seconds (272.85 k allocations: 57.247 GiB, 9.10% gc time)
#   0.062160 seconds (6.36 k allocations: 63.793 MiB)
# 558.039591 seconds (215.29 M allocations: 845.919 GiB, 6.77% gc time)
# β = 0.08199999999999999
# 1322.210196 seconds (3.79 G allocations: 454.185 GiB, 24.89% gc time)
# hst[end] = 0.004166774810219297
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176871.93814268304
#  46.798650 seconds (272.85 k allocations: 57.247 GiB, 9.13% gc time)
#   0.061095 seconds (6.36 k allocations: 63.793 MiB)
# 520.534273 seconds (200.94 M allocations: 789.525 GiB, 6.77% gc time)
# β = 0.033999999999999996
# 1320.133288 seconds (3.79 G allocations: 454.185 GiB, 24.88% gc time)
# hst[end] = 0.003955985136590771
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176703.06286837434
#  47.151942 seconds (272.86 k allocations: 57.247 GiB, 9.21% gc time)
#   0.062753 seconds (6.36 k allocations: 63.793 MiB)
# 483.225538 seconds (186.59 M allocations: 733.130 GiB, 6.79% gc time)
# β = 0.121
# 1323.730978 seconds (3.79 G allocations: 454.185 GiB, 24.82% gc time)
# hst[end] = 0.0037368033434255704
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176621.2025051913
#  46.930437 seconds (272.89 k allocations: 57.247 GiB, 9.16% gc time)
#   0.061562 seconds (6.36 k allocations: 63.793 MiB)
# 409.429893 seconds (157.88 M allocations: 620.341 GiB, 6.78% gc time)
# β = 0.031000000000000007
# 1319.923749 seconds (3.79 G allocations: 454.185 GiB, 24.84% gc time)
# hst[end] = 0.0036435437778068506
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176537.16313558197
#  46.893947 seconds (272.87 k allocations: 57.247 GiB, 9.12% gc time)
#   0.061910 seconds (6.36 k allocations: 63.793 MiB)
# 520.366495 seconds (200.94 M allocations: 789.525 GiB, 6.79% gc time)
# β = 0.145
# 1323.046735 seconds (3.79 G allocations: 454.185 GiB, 24.82% gc time)
# hst[end] = 0.003634983413591447
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176512.3164249083
#  46.954447 seconds (272.90 k allocations: 57.247 GiB, 9.11% gc time)
#   0.061314 seconds (6.36 k allocations: 63.793 MiB)
# 372.669800 seconds (143.53 M allocations: 563.946 GiB, 6.83% gc time)
# β = 0.025
# 1320.262070 seconds (3.79 G allocations: 454.185 GiB, 24.85% gc time)
# hst[end] = 0.003551766211457704
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176411.85322022895
#  47.001336 seconds (272.83 k allocations: 57.247 GiB, 9.15% gc time)
#   0.061988 seconds (6.36 k allocations: 63.793 MiB)
# 669.198847 seconds (258.35 M allocations: 1015.103 GiB, 6.78% gc time)
# β = 0.7689999999999999
# 1323.497623 seconds (3.79 G allocations: 454.185 GiB, 24.87% gc time)
# hst[end] = 0.004111018857002145
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176581.45331172715
#  46.879567 seconds (272.88 k allocations: 57.247 GiB, 9.12% gc time)
#   0.061180 seconds (6.36 k allocations: 63.793 MiB)
# 557.668081 seconds (215.29 M allocations: 845.919 GiB, 6.78% gc time)
# β = 0.023499999999999997
# 1320.410465 seconds (3.79 G allocations: 454.185 GiB, 24.85% gc time)
# hst[end] = 0.003117930259692479
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176248.28539343696
#  47.152466 seconds (272.86 k allocations: 57.247 GiB, 9.07% gc time)
#   0.061968 seconds (6.36 k allocations: 63.793 MiB)
# 448.458252 seconds (172.23 M allocations: 676.735 GiB, 6.80% gc time)
# β = 0.061
# 1324.388742 seconds (3.79 G allocations: 454.185 GiB, 24.85% gc time)
# hst[end] = 0.003906382541836885
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176355.15722181264
#  47.060064 seconds (272.90 k allocations: 57.247 GiB, 9.11% gc time)
#   0.061715 seconds (6.36 k allocations: 63.793 MiB)
# 446.817897 seconds (172.23 M allocations: 676.735 GiB, 6.74% gc time)
# β = 0.061
# 1322.032738 seconds (3.79 G allocations: 454.185 GiB, 24.82% gc time)
# hst[end] = 0.0033010681201208806
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176140.4711444239
#  47.006064 seconds (272.88 k allocations: 57.247 GiB, 9.08% gc time)
#   0.062746 seconds (6.36 k allocations: 63.793 MiB)
# 523.461834 seconds (200.94 M allocations: 789.525 GiB, 6.79% gc time)
# β = 0.05500000000000001
# 1324.724154 seconds (3.79 G allocations: 454.185 GiB, 24.83% gc time)
# hst[end] = 0.0036149707959675886
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176186.74601588945
#  47.089529 seconds (272.86 k allocations: 57.247 GiB, 9.09% gc time)
#   0.062701 seconds (6.36 k allocations: 63.793 MiB)
# 484.611836 seconds (186.59 M allocations: 733.130 GiB, 6.77% gc time)
# β = 0.073
# 1325.181513 seconds (3.79 G allocations: 454.185 GiB, 24.80% gc time)
# hst[end] = 0.0031166664076968356
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176036.37640164496
#  46.818597 seconds (272.88 k allocations: 57.247 GiB, 9.12% gc time)
#   0.062126 seconds (6.36 k allocations: 63.793 MiB)
# 450.064507 seconds (172.23 M allocations: 676.735 GiB, 6.79% gc time)
# β = 0.037
# 1322.808182 seconds (3.79 G allocations: 454.185 GiB, 24.84% gc time)
# hst[end] = 0.003540501539555946
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -176059.26547382516
#  47.014902 seconds (272.84 k allocations: 57.247 GiB, 9.08% gc time)
#   0.061463 seconds (6.36 k allocations: 63.793 MiB)
# 559.310657 seconds (215.29 M allocations: 845.919 GiB, 6.77% gc time)
# β = 0.16899999999999998
# 1322.816423 seconds (3.79 G allocations: 454.185 GiB, 24.84% gc time)
# hst[end] = 0.0029970989205925966
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175941.06590859397
#  47.353478 seconds (272.89 k allocations: 57.247 GiB, 9.16% gc time)
#   0.061466 seconds (6.36 k allocations: 63.793 MiB)
# 485.620885 seconds (186.59 M allocations: 733.130 GiB, 6.77% gc time)
# β = 0.024999999999999998
# 1323.676406 seconds (3.79 G allocations: 454.185 GiB, 24.84% gc time)
# hst[end] = 0.00319652763794188
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175905.02118205398
#  47.063153 seconds (272.85 k allocations: 57.247 GiB, 9.14% gc time)
#   0.061868 seconds (6.36 k allocations: 63.793 MiB)
# 595.857567 seconds (229.64 M allocations: 902.314 GiB, 6.77% gc time)
# β = 0.5770000000000001
# 1327.477898 seconds (3.79 G allocations: 454.185 GiB, 24.81% gc time)
# hst[end] = 0.003437213370717819
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175965.6966768378
#  46.971407 seconds (272.89 k allocations: 57.247 GiB, 9.12% gc time)
#   0.061789 seconds (6.36 k allocations: 63.793 MiB)
# 484.320666 seconds (186.59 M allocations: 733.130 GiB, 6.78% gc time)
# β = 0.027999999999999997
# 1321.234245 seconds (3.79 G allocations: 454.185 GiB, 24.84% gc time)
# hst[end] = 0.002691338309150845
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175766.1848153627
#  46.927922 seconds (272.88 k allocations: 57.247 GiB, 9.14% gc time)
#   0.061787 seconds (6.36 k allocations: 63.793 MiB)
# 485.384212 seconds (186.59 M allocations: 733.130 GiB, 6.76% gc time)
# β = 0.121
# 1324.463081 seconds (3.79 G allocations: 454.185 GiB, 24.87% gc time)
# hst[end] = 0.0037176101851952165
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175934.04919376454
#  47.003004 seconds (272.90 k allocations: 57.247 GiB, 9.11% gc time)
#   0.061729 seconds (6.36 k allocations: 63.793 MiB)
# Progress: 100%|█████████████████████████████████████████| Time: 1 days, 8:05:41
# 531.099180 seconds (200.94 M allocations: 789.525 GiB, 6.81% gc time)
# β = 0.0385
# 1321.466961 seconds (3.79 G allocations: 454.185 GiB, 24.83% gc time)
# hst[end] = 0.002630604020063616
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175632.3394102237
#  46.730114 seconds (272.86 k allocations: 57.247 GiB, 9.16% gc time)
#   0.061488 seconds (6.36 k allocations: 63.793 MiB)
# 558.957820 seconds (215.29 M allocations: 845.919 GiB, 6.78% gc time)
# β = 0.28900000000000003
# 1322.933208 seconds (3.79 G allocations: 454.185 GiB, 24.87% gc time)
# hst[end] = 0.002962363107783264
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175699.19838889822
#  46.822970 seconds (272.86 k allocations: 57.247 GiB, 9.13% gc time)
#   0.060796 seconds (6.36 k allocations: 63.793 MiB)
# 559.141267 seconds (215.29 M allocations: 845.919 GiB, 6.79% gc time)
# β = 0.023499999999999993
# 1324.804287 seconds (3.79 G allocations: 454.185 GiB, 24.82% gc time)
# hst[end] = 0.0027507082455674355
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175588.3801930294
#  47.075972 seconds (272.86 k allocations: 57.247 GiB, 9.13% gc time)
#   0.061531 seconds (6.36 k allocations: 63.793 MiB)
# 523.927980 seconds (200.94 M allocations: 789.525 GiB, 6.80% gc time)
# β = 0.241
# 1325.871771 seconds (3.79 G allocations: 454.185 GiB, 24.85% gc time)
# hst[end] = 0.0035968163881448605
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175721.12648267517
#  46.982671 seconds (272.87 k allocations: 57.247 GiB, 9.11% gc time)
#   0.062066 seconds (6.36 k allocations: 63.793 MiB)
# 410.734210 seconds (157.88 M allocations: 620.341 GiB, 6.77% gc time)
# β = 0.031000000000000003
# 1325.797498 seconds (3.79 G allocations: 454.185 GiB, 24.75% gc time)
# hst[end] = 0.0026534035270747254
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175507.44897983235
#  46.931892 seconds (272.87 k allocations: 57.247 GiB, 9.09% gc time)
#   0.068538 seconds (6.36 k allocations: 63.793 MiB)
# 487.011020 seconds (186.59 M allocations: 733.130 GiB, 6.78% gc time)
# β = 0.121
# 1324.790776 seconds (3.79 G allocations: 454.185 GiB, 24.78% gc time)
# hst[end] = 0.0035668360393459977
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175641.17198162896
#  47.136443 seconds (272.85 k allocations: 57.247 GiB, 9.17% gc time)
#   0.063077 seconds (6.36 k allocations: 63.793 MiB)
# 488.178801 seconds (186.59 M allocations: 733.130 GiB, 6.79% gc time)
# β = 0.034
# 1325.139095 seconds (3.79 G allocations: 454.185 GiB, 24.85% gc time)
# hst[end] = 0.002600349342281276
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175416.641757808
#  47.005822 seconds (272.86 k allocations: 57.247 GiB, 9.11% gc time)
#   0.062112 seconds (6.36 k allocations: 63.793 MiB)
# 562.066652 seconds (215.29 M allocations: 845.919 GiB, 6.79% gc time)
# β = 0.16899999999999998
# 1327.320500 seconds (3.79 G allocations: 454.185 GiB, 24.80% gc time)
# hst[end] = 0.0026289239657523436
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175406.4114397571
#  46.861972 seconds (272.88 k allocations: 57.247 GiB, 9.12% gc time)
#   0.061287 seconds (6.36 k allocations: 63.793 MiB)
# 486.648089 seconds (186.59 M allocations: 733.130 GiB, 6.78% gc time)
# β = 0.027999999999999997
# 1325.524933 seconds (3.79 G allocations: 454.185 GiB, 24.83% gc time)
# hst[end] = 0.0026606283068425704
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175363.0158773854
#  46.850359 seconds (272.85 k allocations: 57.247 GiB, 9.14% gc time)
#   0.062429 seconds (6.36 k allocations: 63.793 MiB)
# 559.210931 seconds (215.29 M allocations: 845.919 GiB, 6.78% gc time)
# β = 0.157
# 1324.471837 seconds (3.79 G allocations: 454.185 GiB, 24.86% gc time)
# hst[end] = 0.002745024498749479
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175363.6277965035
#  46.813572 seconds (272.88 k allocations: 57.247 GiB, 9.13% gc time)
#   0.061457 seconds (6.36 k allocations: 63.793 MiB)
# 410.691591 seconds (157.88 M allocations: 620.341 GiB, 6.78% gc time)
# β = 0.031
# 1324.677106 seconds (3.79 G allocations: 454.185 GiB, 24.84% gc time)
# hst[end] = 0.0025634091015969205
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175300.4255190928
#  46.957540 seconds (272.88 k allocations: 57.247 GiB, 9.17% gc time)
#   0.060820 seconds (6.36 k allocations: 63.793 MiB)
# 523.995092 seconds (200.94 M allocations: 789.525 GiB, 6.78% gc time)
# β = 0.14500000000000002
# 1323.544379 seconds (3.79 G allocations: 454.185 GiB, 24.83% gc time)
# hst[end] = 0.002635063505865461
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175295.0171297082
#  47.190753 seconds (272.89 k allocations: 57.247 GiB, 9.18% gc time)
#   0.061393 seconds (6.36 k allocations: 63.793 MiB)
# 374.940960 seconds (143.53 M allocations: 563.946 GiB, 6.79% gc time)
# β = 0.025
# 1325.498935 seconds (3.79 G allocations: 454.185 GiB, 24.84% gc time)
# hst[end] = 0.0025953549803629157
# CMBrings.ll_ϕf′(ϕ_cr, f′_cr, Φ_ring, EB_ring; data = d, Ł, Ð⁻¹, Pr, Beam_ring, Noise_ring⁻¹) = -175250.46445414948
#  47.157938 seconds (272.87 k allocations: 57.247 GiB, 9.12% gc time)
#   0.061860 seconds (6.36 k allocations: 63.793 MiB)
# 601.646039 seconds (229.64 M allocations: 902.314 GiB, 6.76% gc time)
# β = 0.40900000000000003

# %% [markdown]
# ϕ_cr[:] |> matshow; colorbar()
# ϕ[:] |> matshow; colorbar()

# %%
@sblock let ϕtru = ϕ, ϕest = ϕ_cr, ϕ2v!, φ, θ, hide_plots
    hide_plots && return
    viz = function (ϕ0)
        v = (deepcopy(ϕ0[:]), deepcopy(ϕ0[:]))
        ϕ2v!(v, ϕ0[:])
        v
    end
    imgs = Dict(1=>viz(ϕtru)[1], 3=>viz(ϕest)[1],
                2=>viz(ϕtru)[2], 4=>viz(ϕest)[2])
    txt  = Dict(1=>"true", 3=>"est")
    fig, ax = CMBrings.diskplot(
        imgs, φ', π.-θ; txt=txt,
        figsize=(10,16), nrows=2, fontsize=14
    )
    return nothing
end
# Out:
# Figure(PyObject <Figure size 1000x1600 with 8 Axes>)

# %%
@sblock let ϕtru = ϕ, ϕest = ϕ_cr, ϕ2v!, φ, θ, hide_plots
    hide_plots && return
    imgs = Dict(1=>ϕtru[:], 2=>ϕest[:])
    txt  = Dict(1=>"true", 2=>"est")
    fig, ax = CMBrings.diskplot(
        imgs, φ', π.-θ; txt=txt,
        figsize=(10,8), nrows=1, fontsize=14
    )
    return nothing
end
# Out:
# Figure(PyObject <Figure size 1000x800 with 4 Axes>)

# %%
@sblock let f_cr, qu, φ, θ, hide_plots

    hide_plots && return

    imgs = Dict(1=>real(f_cr[:]), 2=>imag(f_cr[:]))
    imgs = Dict(
        1=>real(f_cr[:]), 2=>imag(f_cr[:]),
        3=>real(qu[:]),   4=>imag(qu[:])
        )
    txt  = Dict(
        1=>"Q wf",     2=>"U wf",
        3=>"Q true",   4=>"U true",
    )
    fig, ax = CMBrings.diskplot(
        imgs, φ', π.-θ; txt=txt,
        figsize=(10,16), nrows=2, fontsize=14
    )
    return nothing

end
# Out:
# Figure(PyObject <Figure size 1000x1600 with 8 Axes>)

# %%
@sblock let ϕtru = ϕ, ϕest = ϕ_cr, ϕ2v!, φ, θ, hide_plots
    hide_plots && return
    viz = function (ϕ0)
        v = (deepcopy(ϕ0[:]), deepcopy(ϕ0[:]))
        ϕ2v!(v, ϕ0[:])
        v
    end
    imgs = Dict(1=>viz(ϕtru)[1], 2=>viz(ϕest)[1],
                3=>viz(ϕtru)[2], 4=>viz(ϕest)[2])
    txt  = Dict(1=>"true", 3=>"true")
    fig, ax = CMBrings.brickplot(
        imgs; txt=txt,
    )
    return nothing
end
# Out:
# Figure(PyObject <Figure size 1427.18x700 with 8 Axes>)
